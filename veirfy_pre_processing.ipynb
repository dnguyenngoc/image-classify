# %%
import os
os.chdir('./backend/app/')
from helpers import image_utils
import matplotlib.pyplot as plt
from helpers.skew import SkewDetect

plt.figure()

skew = SkewDetect()

# %%
data = image_utils.load_datasets('../../datasets/image_classify/train/giay_phep_lai_xe/')

# for item in data:
item = data[8]
image = image_utils.load(item)
plt.imshow(image)
plt.title(item.split('/')[-1])
plt.show()
image = image_utils.pre_process(image)
plt.imshow(image, cmap = 'gray')
plt.title(item.split('/')[-1])
plt.show()
