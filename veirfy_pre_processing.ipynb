# %%
import os
os.chdir('./backend/app/')
from helpers import image_utils
import matplotlib.pyplot as plt
from helpers.skew import SkewDetect

plt.figure()

skew = SkewDetect()

# %%
giay_ra_vien = image_utils.load_datasets('../../datasets/image_classify/train/giay_ra_vien/')

for item in giay_ra_vien:
    print(item)
    image = image_utils.load(item)
    plt.imshow(image)
    plt.title(item.split('/')[-1])
    plt.show()
    image = image_utils.pre_process(image)
    plt.imshow(image, cmap = 'gray')
    plt.title(item.split('/')[-1])
    plt.show()
# Out:
# ../../datasets/image_classify/train/giay_ra_vien\1.jpg
# ../../datasets/image_classify/train/giay_ra_vien\10.jpg
# ../../datasets/image_classify/train/giay_ra_vien\2.jpg
# ../../datasets/image_classify/train/giay_ra_vien\3.jpg
# ../../datasets/image_classify/train/giay_ra_vien\4.jpg
# ../../datasets/image_classify/train/giay_ra_vien\5.jpg
# ../../datasets/image_classify/train/giay_ra_vien\6.jpg
# ../../datasets/image_classify/train/giay_ra_vien\7.jpg
# ../../datasets/image_classify/train/giay_ra_vien\8.jpg
# ../../datasets/image_classify/train/giay_ra_vien\9.jpg
